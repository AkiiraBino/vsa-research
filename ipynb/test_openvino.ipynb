# %%
import ultralytics

# %%
model = ultralytics.YOLO("/home/akiirabino/video-anal/ipynb/model/yolov8l-d3-e100-default-best_openvino_model")
# Out:
# WARNING ⚠️ Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.

# %%
import os
import cv2
root_dir = "/home/akiirabino/video-anal/ipynb/dataset-1/train/images/"
images = [cv2.resize(cv2.imread(root_dir + path), (640,640)) for i, path in enumerate(os.listdir(root_dir)) if i < 100]

# %%
len(images)
# Out:
# 100

# %%
model(images,)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 model(images)
#
# File ~/miniconda3/envs/ipynb/lib/python3.12/site-packages/ultralytics/engine/model.py:177, in Model.__call__(self, source, stream, **kwargs)
#     154 def __call__(
#     155     self,
#     156     source: Union[str, Path, int, list, tuple, np.ndarray, torch.Tensor] = None,
#     157     stream: bool = False,
#     158     **kwargs,
#     159 ) -> list:
#     160     """
#     161     An alias for the predict method, enabling the model instance to be callable.
#     162
#    (...)
#     175         (List[ultralytics.engine.results.Results]): A list of prediction results, encapsulated in the Results class.
#     176     """
# --> 177     return self.predict(source, stream, **kwargs)
#
# ...

# %%
result = []
for i in images:
    result.append(model(i))
# Out:
# Loading /home/akiirabino/video-anal/ipynb/model/yolov8l-d3-e100-default-best_openvino_model for OpenVINO inference...
# Using OpenVINO LATENCY mode for batch=1 inference...
# mbind failed: Function not implemented
# mbind failed: Function not implemented
# mbind failed: Function not implemented
# mbind failed: Function not implemented
# mbind failed: Function not implemented
# mbind failed: Function not implemented
# mbind failed: Function not implemented
# mbind failed: Function not implemented
# mbind failed: Function not implemented
# mbind failed: Function not implemented
# mbind failed: Function not implemented
# mbind failed: Function not implemented
# mbind failed: Function not implemented
# mbind failed: Function not implemented
# mbind failed: Function not implemented
# mbind failed: Function not implemented
# mbind failed: Function not implemented
# mbind failed: Function not implemented
# mbind failed: Function not implemented
# mbind failed: Function not implemented
# ...

# %%
import numpy as np
time = []
for i in result:
    time.append(i[0].speed["inference"])
np.mean(time)
# Out:
# 480.40501594543457
